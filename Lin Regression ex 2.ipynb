# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\Shashwat\Desktop\DataSets-master\Housing_Data.csv")

# %%
data
# Out:
#      Unnamed: 0     price  lotsize  bedrooms  bathrms  stories driveway  \
# 0             1   42000.0     5850         3        1        2      yes
# 1             2   38500.0     4000         2        1        1      yes
# 2             3   49500.0     3060         3        1        1      yes
# 3             4   60500.0     6650         3        1        2      yes
# 4             5   61000.0     6360         2        1        1      yes
# 5             6   66000.0     4160         3        1        1      yes
# 6             7   66000.0     3880         3        2        2      yes
# 7             8   69000.0     4160         3        1        3      yes
# 8             9   83800.0     4800         3        1        1      yes
# 9            10   88500.0     5500         3        2        4      yes
# 10           11   90000.0     7200         3        2        1      yes
# 11           12   30500.0     3000         2        1        1       no
# ...

# %%
Y_out=data['price']

# %%
X_input=data['lotsize']

# %%
X_train=X_input[:-46]
X_test=X_input[-46:]
Y_train=Y_out[:-46]
Y_test=Y_out[-46:]

# %%
#Reshape
X_train=X_train.values.reshape(len(X_train),1)
X_test=X_test.values.reshape(len(X_test),1)
Y_train=Y_train.values.reshape(len(Y_train),1)
Y_test=Y_test.values.reshape(len(Y_test),1)

# %%
from sklearn import linear_model

# %%
myobj=linear_model.LinearRegression()

# %%
mymodel=myobj.fit(X_train,Y_train)

# %%
yp=mymodel.predict(X_test)

# %%
yp[0]
# Out:
# array([ 75589.2395177])

# %%
Y_test[0]
# Out:
# array([ 67900.])

# %%
import numpy as np

# %%
from sklearn import metrics

# %%
np.sqrt(metrics.mean_squared_error(Y_test,yp))
# Out:
# 24492.997647654309

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(X_test,Y_test,'r*')
plt.plot(X_test,yp)
plt.show()
